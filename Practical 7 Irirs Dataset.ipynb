# %% [markdown]
# # Practical 7

# %% [markdown]
# # Performing EDA on IRIS Dataset and creating different Graphs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# 1. Import the Dataset and create the data frame from it

# %%
iris = pd.read_csv("D:/Machine Learning/IRIS.csv")  #importing the dataset
iris  #viewing the dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [raw]
# 2. Give the basic understanding of data, by interpret it (tell whether the data is balance or not)

# %%
iris.describe()  #Gives the basic numerical statistical values of the data
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull()  #return True if there is null and False if no null value
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()  #Gives the column vise sum of null values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.columns  #Returns the column heading of the dataset
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.shape  #Gives the structure of the dataset
# Out:
# (150, 5)

# %%
iris.value_counts("species")  #counts the no. of values of each category
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
fig = plt.figure(figsize= (5,2), dpi = 300)
sns.heatmap(data.corr(),annot = True)
plt.show()

# %% [raw]
#  Create a scatter plot to analysis sepal length and sepal breadth, Interpret the  observation (whether positive, negative, null correlation)

# %%
plt.scatter(iris['sepal_length'], iris['sepal_width'])  #Creating scatterplot and defining the x axis and y axis
plt.title('Sepal Length vs Sepal Width')
plt.ylabel('Sepal Width')
plt.xlabel('Sepal Length')
plt.grid()
plt.show()

# %%
sns.scatterplot(x = "sepal_length", y= "sepal_width", data = iris, hue = "species")  #sepal length and sepal width are not good predictors
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = "petal_length", y= "petal_width", data = iris, hue = "species")  #petal length and petal width are good predictors
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='petal_width'>

# %% [raw]
# Create a pair plot of 4 features namely sepal length, sepal breadth, petal length, petal breadth and tell the correlation.

# %%
data = iris[['sepal_length','sepal_width','petal_length','petal_width' ]]  #Creating the pairplot
sns.pairplot(data)
plt.grid()
plt.show()

# %% [markdown]
# Create a distribution plot for petal length and sepal width.

# %%
sns.distplot(iris['sepal_length'])  #Creating the histogram
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.grid()
plt.show()
# Out:
# C:\Users\ANIKET KUMAR\AppData\Local\Temp\ipykernel_4300\2314918375.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['sepal_length'])  #Creating the histogram

# %%
sns.distplot(iris['sepal_width'])  #Creating the histogram
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Width')
plt.grid()
plt.show()
# Out:
# C:\Users\ANIKET KUMAR\AppData\Local\Temp\ipykernel_4300\2596226802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['sepal_width'])  #Creating the histogram

# %% [raw]
# Create a box n whisker plot for petal length and visualise the outlier if any

# %%
sns.set_style('whitegrid')  
sns.boxplot(x='petal_length', y='species', data = iris)  #Creating the box plot
plt.show()

# %%
sns.set_style('whitegrid')
sns.boxplot(x='species', y='petal_length', data = iris)
plt.title('Category and Petal Length')
plt.show()
